# %% [markdown]
# # 🤖 Experiment 0: Introduction to Machine Learning and Tools
#
# Date: *26/12/2025*
#
#
# ---

# %% [markdown]
# ## Aim
# To understand the basics of Machine Learning and familiarize with Jupyter Notebook and Google Colab.

# %% [markdown]
# ## Introduction to Machine Learning
#
# Machine Learning (ML) is a field of Artificial Intelligence that allows computers to learn from data and make predictions.
#
# ML systems improve performance automatically through experience without being explicitly programmed.

# %% [markdown]
# ## Types of Machine Learning
#
# 1. Supervised Learning
#    - Uses labeled data
#    - Example: Regression, Classification
#
# 2. Unsupervised Learning
#    - Uses unlabeled data
#    - Example: Clustering
#
# 3. Reinforcement Learning
#    - Learns through rewards and punishments

# %% [markdown]
# ## Jupyter Notebook
#
# Jupyter Notebook is an open-source tool used for data science and ML.
#
# Features:
# - Code execution in cells
# - Visualization support
# - Easy documentation using Markdown

# %% [markdown]
# ## Google Colab
#
# Google Colab is a cloud-based platform to run Python notebooks.
#
# Advantages:
# - No installation required
# - Free GPU support
# - Easy sharing

# %% [markdown]
# ## Common Errors in ML Lab

# %% [markdown]
# 1. FileNotFoundError
#    - Dataset not uploaded or wrong filename
#
# 2. ModuleNotFoundError
#    - Library not installed
#
# 3. ValueError
#    - Wrong data type or missing values
#
# 4. NameError
#    - Variable used before defining
#
# 5. IndentationError
#    - Incorrect spacing in code
#
# 6. SyntaxError
#    - Missing brackets or colons

# %% [markdown]
# ## Basic Python Demo

# %%
print("Hello Machine Learning")
# Out:
# Hello Machine Learning

# %% [markdown]
# ## Simple Arithmetic Operation

# %%
a = 10
b = 5

print("Addition:", a+b)
print("Multiplication:", a*b)
# Out:
# Addition: 15
# Multiplication: 50

# %% [markdown]
# ## Numpy Demo

# %%
import numpy as np

arr = np.array([1,2,3,4,5])
print("Array:", arr)
print("Mean:", arr.mean())
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0

# %% [markdown]
# ## Pandas Demo

# %%
import pandas as pd

data = {'Name':['A','B','C'],
        'Marks':[80,90,85]}

df = pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     80
# 1    B     90
# 2    C     85

# %% [markdown]
# ## Matplotlib Visualization Demo

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [10,20,25,30,40]

plt.plot(x,y)
plt.title("Simple Line Plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %% [markdown]
# ## Bar Graph Demo

# %%
students = ['A','B','C','D']
marks = [80,90,75,85]

plt.bar(students, marks)
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# ## Result
# Basic concepts of Machine Learning and tools were understood successfully.

# %% [markdown]
# ## Conclusion
# Machine Learning tools like Jupyter and Colab make ML implementation easier.
# Understanding errors helps in debugging ML programs effectively.
